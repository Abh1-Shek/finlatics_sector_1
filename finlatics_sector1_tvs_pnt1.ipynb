# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
company_names = ['Hero Motocorp', 'Honda', 'TVS', 'Bajaj', 'Royal-Enfield', 'others']

# %%
market_share = [39.25, 24.55, 14.35, 11.30, 3.58, 6.97]

# %%
plt.pie(market_share, labels = company_names, autopct = '%.1f%%', radius = 1)
plt.savefig('finlatics_automotive_market_share_tvs.png', dpi = 300)
plt.show()
